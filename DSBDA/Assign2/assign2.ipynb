# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LR
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# %%
dataset=pd.read_csv("StudentsPerformance_modified.csv",encoding='latin1')
dataset.shape
# Out:
# (131114, 8)

# %%
dataset.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
dataset.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...          72.0          74.0
# 1  female        group C  ...          90.0          88.0
# 2  female        group B  ...          95.0          93.0
# 3    male        group A  ...          57.0          44.0
# 4    male        group C  ...          78.0          75.0
#
# [5 rows x 8 columns]

# %%
mathIsDigit = pd.DataFrame(dataset['math score'].str.isdigit())

# %%
dataset[mathIsDigit['math score']==False]
# Out:
#                                       gender  ... writing score
# 432                                     male  ...          55.0
# 433                                   female  ...          50.0
# 434                                     male  ...          66.0
# 435                                     male  ...          53.0
# 436                                     male  ...          64.0
# 437                                     male  ...          73.0
# 65562   ¢:Ø?â^ûÈH«TúqiéBÖå2ø``~WÖA¶N\tòL  ...           NaN
# 131098  ¢:Ø?â^ûÈH«TúqiéBÖå2ø``~WÖA¶N\tòL  ...           NaN
#
# [8 rows x 8 columns]

# %%
dataset=dataset.replace('?',np.nan)

# %%
dataset=dataset.replace('úÀyÝìº¯60RC·y×:ÝØÙÛ',np.nan)
dataset[mathIsDigit['math score']==False]
# Out:
#                                       gender  ... writing score
# 432                                     male  ...          55.0
# 433                                   female  ...          50.0
# 434                                     male  ...          66.0
# 435                                     male  ...          53.0
# 436                                     male  ...          64.0
# 437                                     male  ...          73.0
# 65562   ¢:Ø?â^ûÈH«TúqiéBÖå2ø``~WÖA¶N\tòL  ...           NaN
# 131098  ¢:Ø?â^ûÈH«TúqiéBÖå2ø``~WÖA¶N\tòL  ...           NaN
#
# [8 rows x 8 columns]

# %%
labelencoder=LabelEncoder()
dataset_new=dataset.copy()
dataset_new['parental level of education']=labelencoder.fit_transform(dataset_new['parental level of education'])
dataset_new["test preparation course"] = labelencoder.fit_transform(dataset_new["test preparation course"])
dataset_new["lunch"] = labelencoder.fit_transform(dataset_new["lunch"])

# %%
dataset_new.head()
# Out:
#    gender race/ethnicity  ...  reading score  writing score
# 0  female        group B  ...           72.0           74.0
# 1  female        group C  ...           90.0           88.0
# 2  female        group B  ...           95.0           93.0
# 3    male        group A  ...           57.0           44.0
# 4    male        group C  ...           78.0           75.0
#
# [5 rows x 8 columns]

# %%
dataset_new.isnull().sum()
# Out:
# gender                              2
# race/ethnicity                 130596
# parental level of education         0
# lunch                               0
# test preparation course             0
# math score                     130690
# reading score                  130677
# writing score                  130678
# dtype: int64

# %%
# !pip install missingno

import missingno as msno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from missingno) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from missingno) (3.10.0)
# Requirement already satisfied: scipy in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from missingno) (1.15.2)
# Requirement already satisfied: seaborn in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\tanay\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno as msno

# %%
msno.matrix(dataset_new)
# Out:
# <Axes: >

# %%
dataset_new.describe()
# Out:
#        parental level of education          lunch  ...  reading score  writing score
# count                131114.000000  131114.000000  ...     437.000000     436.000000
# mean                     20.950982       5.987507  ...      65.608696      66.857798
# std                       0.838230       0.221480  ...      18.790009      15.364924
# min                       0.000000       0.000000  ...       3.000000      10.000000
# 25%                      21.000000       6.000000  ...      56.000000      56.750000
# 50%                      21.000000       6.000000  ...      68.000000      68.000000
# 75%                      21.000000       6.000000  ...      78.000000      77.000000
# max                      21.000000       6.000000  ...     100.000000     100.000000
#
# [8 rows x 5 columns]

# %%
dataset_new['math score'].str.isdigit().count()
# Out:
# np.int64(424)

# %%
dataset_new.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education      int64
# lunch                            int64
# test preparation course          int64
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
numeric_cols=['test preparation course','math score','reading score','writing score']
medianfiller=lambda x: x.fillna(x.median())
dataset_new['math score']=dataset_new['math score'].astype('float64')

# %%
import seaborn as sns

sns.distplot(dataset_new["writing score"])
# Out:
# C:\Users\tanay\AppData\Local\Temp\ipykernel_20292\4255176207.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset_new["writing score"])
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()

# %%
dataset_new[['writing score']] = s.fit_transform(dataset_new[['writing score']])

# %%
sns.distplot(dataset_new["writing score"])
# Out:
# C:\Users\tanay\AppData\Local\Temp\ipykernel_20292\1248051489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset_new["writing score"])
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
for column in numeric_cols:
    plt.figure(figsize=(17,1))
    sns.boxplot(data=dataset_new, x=column)

# %%
plt.figure(figsize=(10,12))
sns.boxplot(x="variable", y="value", data=pd.melt(dataset_new[numeric_cols]))
plt.show()

# %%
numeric_data = dataset_new[numeric_cols]  # Ensure this contains only numeric columns
numeric_data = numeric_data.apply(pd.to_numeric, errors='coerce')  # Convert all values to numeric, invalid parsing will be set to NaN

# %%
# Replace NaNs in numeric columns only with their median
dataset_new.fillna(dataset_new.select_dtypes(include='number').median(), inplace=True)

# %%
Q1 = dataset_new.quantile(0.25)
Q3 = dataset_new.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 Q1 = dataset_new.quantile(0.25)
#       2 Q3 = dataset_new.quantile(0.75)
#       3 IQR = Q3 - Q1
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:12146, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12140 axis = self._get_axis_number(axis)
#   12142 if not is_list_like(q):
#   12143     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12144     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146     res_df = self.quantile(
#   12147         [q],  # type: ignore[list-item]
#   12148         axis=axis,
#   12149         numeric_only=numeric_only,
#   12150         interpolation=interpolation,
#   12151         method=method,
#   12152     )
#   12153     if method == "single":
#   12154         res = res_df.iloc[0]
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:12191, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12187     raise ValueError(
#   12188         f"Invalid method: {method}. Method must be in {valid_method}."
#   12189     )
#   12190 if method == "single":
# > 12191     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12192 elif method == "table":
#   12193     valid_interpolation = {"nearest", "lower", "higher"}
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1549, in BlockManager.quantile(self, qs, interpolation)
#    1545 new_axes = list(self.axes)
#    1546 new_axes[1] = Index(qs, dtype=np.float64)
#    1548 blocks = [
# -> 1549     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1550 ]
#    1552 return type(self)(blocks, new_axes)
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:1891, in Block.quantile(self, qs, interpolation)
#    1888 assert self.ndim == 2
#    1889 assert is_list_like(qs)  # caller is responsible for this
# -> 1891 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1892 # ensure_block_shape needed for cases where we start with EA and result
#    1893 #  is ndarray, e.g. IntegerArray, SparseArray
#    1894 result = ensure_block_shape(result, ndim=2)
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:199, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     195 if mask.any():
#     196     # Caller is responsible for ensuring mask shape match
#     197     assert mask.shape == values.shape
#     198     result = [
# --> 199         _nanpercentile_1d(val, m, qs, na_value, interpolation=interpolation)
#     200         for (val, m) in zip(list(values), list(mask))
#     201     ]
#     202     if values.dtype.kind == "f":
#     203         # preserve itemsize
#     204         result = np.asarray(result, dtype=values.dtype).T
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\quantile.py:145, in _nanpercentile_1d(values, mask, qs, na_value, interpolation)
#     139 if len(values) == 0:
#     140     # Can't pass dtype=values.dtype here bc we might have na_value=np.nan
#     141     #  with values.dtype=int64 see test_quantile_empty
#     142     # equiv: 'np.array([na_value] * len(qs))' but much faster
#     143     return np.full(len(qs), na_value)
# --> 145 return np.percentile(
#     146     values,
#     147     qs,
#     148     # error: No overload variant of "percentile" matches argument
#     149     # types "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]"
#     150     # , "Dict[str, str]"  [call-overload]
#     151     method=interpolation,  # type: ignore[call-overload]
#     152 )
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4273, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4270     if np.any(weights < 0):
#    4271         raise ValueError("Weights must be non-negative.")
# -> 4273 return _quantile_unchecked(
#    4274     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4550, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4541 def _quantile_unchecked(a,
#    4542                         q,
#    4543                         axis=None,
#    (...)
#    4547                         keepdims=False,
#    4548                         weights=None):
#    4549     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4550     return _ureduce(a,
#    4551                     func=_quantile_ureduce_func,
#    4552                     q=q,
#    4553                     weights=weights,
#    4554                     keepdims=keepdims,
#    4555                     axis=axis,
#    4556                     out=out,
#    4557                     overwrite_input=overwrite_input,
#    4558                     method=method)
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:3894, in _ureduce(a, func, keepdims, **kwargs)
#    3891             index_out = (0, ) * nd
#    3892             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3894 r = func(a, **kwargs)
#    3896 if out is not None:
#    3897     return out
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4727, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4725         arr = a.copy()
#    4726         wgt = weights
# -> 4727 result = _quantile(arr,
#    4728                    quantiles=q,
#    4729                    axis=axis,
#    4730                    method=method,
#    4731                    out=out,
#    4732                    weights=wgt)
#    4733 return result
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4859, in _quantile(arr, quantiles, axis, method, out, weights)
#    4857         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4858         gamma = gamma.reshape(result_shape)
# -> 4859         result = _lerp(previous,
#    4860                     next,
#    4861                     gamma,
#    4862                     out=out)
#    4863 else:
#    4864     # Weighted case
#    4865     # This implements method="inverted_cdf", the only supported weighted
#    4866     # method, which needs to sort anyway.
#    4867     weights = np.asanyarray(weights)
#
# File c:\Users\tanay\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:4653, in _lerp(a, b, t, out)
#    4639 def _lerp(a, b, t, out=None):
#    4640     """
#    4641     Compute the linear interpolation weighted by gamma on each point of
#    4642     two same shape array.
#    (...)
#    4651         Output array.
#    4652     """
# -> 4653     diff_b_a = subtract(b, a)
#    4654     # asanyarray is a stop-gap until gh-13105
#    4655     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
